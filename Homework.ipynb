# %%
#b1
n = int(input())
print(2*n)
# Out:
#  4
# 8

# %%
#b2
a,b = map(int, input().split())
sc = a*a*157/200
dt = a*b - sc

print(f'{dt:.2f}')
# Out:
#  2 4
# 4.86

# %%
#b3
c = input()
a = ord(c)
if( a < 97 ):
    print(chr(a+32))
else:
    print(chr(a-32))
# Out:
#  H
# h

# %%
#b4
c = input()
a = ord(c)
if( a > 64 and a <123 ):
    print(chr(a), "là kí tu alphabet" )
else:
    print(chr(a), "không phải là kí tự alphabet")
# Out:
#  A
# A là kí tu alphabet

# %%
#b5
c = input()
a = ord(c)
if ( a == 65):
    print("Không có chữ cái liền trước")
else:
    print( chr(a+31))
# Out:
#  A
# Không có chữ cái liền trước

# %%
#b6
a , b , c = map(int, input().split())
if( a+b <= c or b+c <= a or c+a <= b):
    print("Khong phai 3 canh cua tam giac")
else:
    p = (a+b+c)/2
    s = p*(p-a)*(p-b)*(p-c)
    print( s**(1/2))
# Out:
#  3 4 5
# 6.0

# %%
#b7
n = input()
for i in range(len(n)):
    if( i == 4 or i == 8):
        print(n[i])
# Out:
#  aaaaabbbbb
# a
# b

# %%
#b8
ten = input("Ten chu ho: ")
trc = int(input("Chi so thang truoc: "))
nay = int(input("Chi so thang nay: "))
t = nay - trc
gia = [
    (50, 1984),      
    (50, 2050),    
    (100, 2380),     
    (100, 2998),      
    (100, 3350),      
    (float('inf'), 3460)
]
tong = 0
for i,j in gia:
    if( t<=0 ):
        break
    else:
        bg = min(t , i )
        tong = tong + bg*j
        t -=bg
print('Ho va ten:', ten)
print('So tien phai tra:', int(tong*27/25))
# Out:
# Ten chu ho:  nvt
# Chi so thang truoc:  2097
# Chi so thang nay:  2278
# Ho va ten: nvt
# So tien phai tra: 426038

# %%
#t1
n = int(input())
if( n%2==0):
    print('chan')
else:
    print('le')
# Out:
#  2
# chan

# %%
#t2
n = int(input())
if(n%10 == 5):
    print('True')
else:
    print('False')
# Out:
#  12
# False

# %%
#t3
n = int(input())
if( n%3==0 and n%5==0):
    print('True')
else:
    print('False')
# Out:
#  11
# False

# %%
#t4
n = int(input())
if( 2025 - n >= 18):
    print('Co')
else:
    print('Khong')
# Out:
#  2007
# Co

# %%
#t5
a,b = map(int, input().split())
if(a == b):
    print('Bang nhau')
else:
    print(max(a,b))
# Out:
#  2 3
# 3

# %%
#t6
c = input()
a = ord(c)
if( a > 64 and a <123 ):
    print(chr(a), "là chữ" )
else:
    if( a>=48 and a<=57):
        print(chr(a), "là số")
    else:
        print(chr(a), "không là chữ cũng không là số")
# Out:
#  /
# / không là chữ cũng không là số

# %%
#t7
d = int(input())
if(d >= 8):
    print('Gioi')
if(d<8 and d>=6.5):
    print('Kha')
if(d<6.5 and d>=5):
    print('TB')
if(d<5):
    print('Yeu')
# Out:
#  8
# Gioi

# %%
#t8
n = int(input())
if ( n%400==0 or (n%4==0 and n%100 != 0)):
    print(n, 'la nam nhuan')
else:
    print(n,'khong la nam nhuan')
# Out:
#  2025
# 2025 khong la nam nhuan

# %%
#t9
n = int(input())
match n:
    case 0:
        print("Không")
    case 1:
        print("Một")
    case 2:
        print("Hai")
    case 3:
        print("Ba")
    case 4:
        print("Bốn")
    case 5:
        print("Năm")
    case 6:
        print("Sáu")
    case 7:
        print("Bảy")
    case 8:
        print("Tám")
    case 9:
        print("Chín")
# Out:
#  5
# Năm

# %%
#t10
d = int(input())
if(d >= 4):
    print('Qua môn')
else:
    print('Học lại')
# Out:
#  5
# Qua mon

# %%
#t11
n = int(input())
print(2025-n)
if( 2025-n >= 18):
    print("Đủ 18 tuổi")
else:
    print("Chưa đủ 18 tuổi")
# Out:
#  2008
# 17
# Chưa đủ 18 tuổi
